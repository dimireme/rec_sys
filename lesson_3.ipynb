# %% [markdown]
# # Домащнее задание 3
#
# ## Коллаборативная фильтрация

# %% [markdown]
# В качестве домашнего задания ответьте на следующие вопросы:

# %% [markdown]
# **1. В чем принципиальные отличия item-item рекомендаций от ALS?**
#
# ItemItemRecomender для рекомендаций ищет ближайших соседей к пользователю, и считает скор каждого товара как среднее по скору этих ближайших соседей. Алгоритм ALS вычисляет скор товара на основании матриц латентных факторов для пользователей и для товаров. В конечном итоге обученный алгоритм ASL будет для похожих пользователей будет выдавать похожие скоры товаров, но это является следствием работы алгоритма. В ItemItemRecomender это основа для расчета рекомендаций.

# %% [markdown]
# **2. Приведите 3 примера весов user-item матрицы для задачи рекоммендаций товаров.**
#
# - Количество покупок товаров пользователем
# - Количество просмотров этого товара
# - Факт покупки
# - Есть лайк товара или нет
# - Суммарное взвешенное значение вышеперечисленных факторов с определенными коэффициентами
#
# В список могут попасть любые метрики, отражающие взаимодействие пользователя и товара.

# %% [markdown]
# **3. Какие ограничения есть у ALS? (Тип информации, линейность/нелинейность факторов и т д)**
